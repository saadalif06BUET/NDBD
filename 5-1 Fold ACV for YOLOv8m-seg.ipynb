# %%
# !nvidia-smi
# Out:
# Fri Oct 24 04:47:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   75C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **Cell 1: Mount Drive and Install Dependencies - This cell mounts Google Drive for accessing the dataset and installs the Ultralytics library for YOLOv8, then checks the installation.**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics -q
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/112.6 GB disk)

# %% [markdown]
# **Cell 2: Import Libraries and Set Hyperparameters - This cell imports necessary libraries, defines the dataset paths, hyperparameters, and a function to count instances in label files.**

# %%
from ultralytics import YOLO
import os
import shutil
import time  # For measuring training time

# Assumptions and placeholders - replace these with your actual values
# 1. Root dataset path: Adjust this to your Google Drive path where the dataset is stored.
#    Expected structure:
#    - root_path/train/Data1/images/ and /labels/, Data2, etc.
#    - root_path/valid/Data1/images/ and /labels/, Data2, etc.
root_path = '/content/drive/MyDrive/5 fold training/5-Fold Baseline'  # REPLACE THIS WITH YOUR ACTUAL PATH

dataset_name = os.path.basename(root_path)  # e.g., '5-Fold v70,Flip H&V,90° Rotate,seed 0'
base_output_dir = '/content/drive/MyDrive/5 fold training/5_fold_ACV_outputs'  # Base folder for all experiments
os.makedirs(base_output_dir, exist_ok=True)

# 2. Image extension: Assuming .jpg; change if different (e.g., '.png')
image_ext = '.jpg'

# 3. Number of classes and class names: Assuming 1 class for biofouling; adjust as needed
nc = 1  # REPLACE IF NEEDED
class_names = ['biofouling']  # REPLACE WITH YOUR CLASS NAMES, e.g., ['class1', 'class2']

# 4. Training hyperparameters: As provided
epochs = 50
batch_size = 16
imgsz = 640
seed = 0
optimizer = 'auto'
lr0 = 0.01
lrf = 0.01
momentum = 0.937
weight_decay = 0.0005
box = 7.5
cls = 0.5
dfl = 1.5
hsv_h = 0.015
hsv_s = 0.7
hsv_v = 0.4
translate = 0.1
scale = 0.5
fliplr = 0.5
mosaic = 1  # Probability, set to 1 for always on

# Paths
train_path = os.path.join(root_path, 'train')
valid_path = os.path.join(root_path, 'valid')

# List of fold folders
fold_folders = ['Data1', 'Data2', 'Data3', 'Data4', 'Data5']

# Function to count instances (objects) from label files
def count_instances(labels_dir):
    total_instances = 0
    for lbl_file in os.listdir(labels_dir):
        if lbl_file.endswith('.txt'):
            with open(os.path.join(labels_dir, lbl_file), 'r') as f:
                total_instances += len(f.readlines())
    return total_instances

# %% [markdown]
# **Cell 3: Prepare Sessions - This cell initializes the list to store results for the 5 training sessions.**

# %%
# Prepare for 5 sessions
session_results = []
session = 1

# %% [markdown]
# **Cell 4: Main Training Loop - This cell runs the loop for each of the 5 sessions, preparing data, training the model, collecting metrics, and printing progress.**

# %%
for left_out in fold_folders:
    print(f"Starting Session {session}/5 (Validation on {left_out})")

    train_folders = [f for f in fold_folders if f != left_out]
    print(f"Training folders: {', '.join(train_folders)}")

    # Create temporary directories for this session
    session_dir = f'/content/session_{session}'
    os.makedirs(session_dir, exist_ok=True)

    train_dir = os.path.join(session_dir, 'train')
    val_dir = os.path.join(session_dir, 'val')

    for d in [train_dir, val_dir]:
        os.makedirs(os.path.join(d, 'images'), exist_ok=True)
        os.makedirs(os.path.join(d, 'labels'), exist_ok=True)

    # Copy train files from the 4 train folders
    for tf in train_folders:
        src_images = os.path.join(train_path, tf, 'images')
        src_labels = os.path.join(train_path, tf, 'labels')
        for img in os.listdir(src_images):
            if img.endswith(image_ext):
                shutil.copy(os.path.join(src_images, img), os.path.join(train_dir, 'images', img))
                lbl = img.replace(image_ext, '.txt')
                if os.path.exists(os.path.join(src_labels, lbl)):
                    shutil.copy(os.path.join(src_labels, lbl), os.path.join(train_dir, 'labels', lbl))

    # Copy val files from the left-out valid folder
    src_images = os.path.join(valid_path, left_out, 'images')
    src_labels = os.path.join(valid_path, left_out, 'labels')
    for img in os.listdir(src_images):
        if img.endswith(image_ext):
            shutil.copy(os.path.join(src_images, img), os.path.join(val_dir, 'images', img))
            lbl = img.replace(image_ext, '.txt')
            if os.path.exists(os.path.join(src_labels, lbl)):
                shutil.copy(os.path.join(src_labels, lbl), os.path.join(val_dir, 'labels', lbl))

    # Count training images and instances
    train_images_dir = os.path.join(train_dir, 'images')
    num_train_images = len([f for f in os.listdir(train_images_dir) if f.endswith(image_ext)])
    train_labels_dir = os.path.join(train_dir, 'labels')
    num_train_instances = count_instances(train_labels_dir)

    # Count validation images and instances
    val_images_dir = os.path.join(val_dir, 'images')
    num_val_images = len([f for f in os.listdir(val_images_dir) if f.endswith(image_ext)])
    val_labels_dir = os.path.join(val_dir, 'labels')
    num_val_instances = count_instances(val_labels_dir)

    print(f"Training: {num_train_images} images, {num_train_instances} instances")
    print(f"Validation: {num_val_images} images, {num_val_instances} instances")

    # Create dataset.yaml for this session
    yaml_content = f"""
path: {session_dir}
train: train/images
val: val/images

nc: {nc}
names: {class_names}
"""
    yaml_path = os.path.join(session_dir, 'data.yaml')
    with open(yaml_path, 'w') as f:
        f.write(yaml_content)

    # Load model
    model = YOLO('yolov8m-seg.pt')  # Pretrained YOLOv8 medium segmentation model

    # Measure training time
    start_time = time.time()

    # Train with hyperparameters
    results = model.train(
        data=yaml_path,
        epochs=100,
        patience=100,
        imgsz=imgsz,
        batch=batch_size,
        seed=seed,
        optimizer=optimizer,
        lr0=lr0,
        lrf=lrf,
        momentum=momentum,
        weight_decay=weight_decay,
        box=box,
        cls=cls,
        dfl=dfl,
        hsv_h=hsv_h,
        hsv_s=hsv_s,
        hsv_v=hsv_v,
        translate=translate,
        scale=scale,
        fliplr=fliplr,
        mosaic=1,
        name=f'yolov8m_seg_session_{session}',  # Save results in runs/segment/yolov8m_seg_session_X
        device=0,  # Use GPU
        plots=True,  # Generate plots
        save=True

    )

    training_time = time.time() - start_time
    print(f"Session {session} Training Time: {training_time:.2f} seconds ({training_time / 60:.2f} minutes)")

    # Save artifacts to custom folder named after dataset + session
    run_dir = results.save_dir  # e.g., '/content/runs/segment/yolov8m_seg_session_1'
    custom_save_dir = os.path.join(base_output_dir, f"{dataset_name},session {session}")
    os.makedirs(custom_save_dir, exist_ok=True)
    shutil.copytree(run_dir, custom_save_dir, dirs_exist_ok=True)  # Copy entire run dir
    print(f"Saved session {session} artifacts (results, weights, plots) to {custom_save_dir}")

    # Collect all requested metrics
    metrics = results.results_dict
    session_results.append({
        'session': session,
        'train_folders': ', '.join(train_folders),
        'val_folder': left_out,
        'num_val_images': num_val_images,
        'num_val_instances': num_val_instances,
        'num_train_images': num_train_images,
        'num_train_instances': num_train_instances,
        'Box_P': metrics['metrics/precision(B)'],
        'Box_R': metrics['metrics/recall(B)'],
        'Box_mAP50': metrics['metrics/mAP50(B)'],
        'Box_mAP50-95': metrics['metrics/mAP50-95(B)'],
        'Mask_P': metrics['metrics/precision(M)'],
        'Mask_R': metrics['metrics/recall(M)'],
        'Mask_mAP50': metrics['metrics/mAP50(M)'],
        'Mask_mAP50-95': metrics['metrics/mAP50-95(M)'],
        'training_time_seconds': training_time
    })

    # Optional: Clean up session dir to save space (comment out if you want to keep)
    shutil.rmtree(session_dir)

    session += 1
# Out:
# Starting Session 1/5 (Validation on Data1)
# Training folders: Data2, Data3, Data4, Data5
# Training: 28 images, 70 instances
# Validation: 7 images, 22 instances
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/session_1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m-seg.pt, momentum=0.937, mosaic=1, multi_scale=False, name=yolov8m_seg_session_15, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/segment/yolov8m_seg_session_15, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   5159603  ultralytics.nn.modules.head.Segment          [1, 32, 192, [192, 384, 576]]
# YOLOv8m-seg summary: 191 layers, 27,240,227 parameters, 27,240,211 gradients, 104.7 GFLOPs
#
# Transferred 531/537 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1336.7±768.1 MB/s, size: 79.5 KB)
# train: Scanning /content/session_1/train/labels... 28 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 28/28 511.6it/s 0.1s
# train: New cache created: /content/session_1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1557.4±1270.7 MB/s, size: 310.7 KB)
# val: Scanning /content/session_1/val/labels... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7 365.6it/s 0.0s
# val: New cache created: /content/session_1/val/labels.cache
# Plotting labels to /content/runs/segment/yolov8m_seg_session_15/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 86 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/segment/yolov8m_seg_session_15
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      7.07G      2.045      5.422      3.326       1.93        135        640: 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          7         22      0.259     0.0455     0.0648     0.0222    0.00286      0.273     0.0247    0.00977
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.09G      1.695       4.96      3.213      1.815         71        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          7         22      0.266     0.0455      0.061     0.0191    0.00286      0.273     0.0208    0.00765
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.12G      1.705       5.14      3.065      1.899         42        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          7         22      0.663      0.273      0.231       0.13      0.552      0.227      0.152      0.105
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.22G      1.458      3.733      2.654      1.637         87        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.752      0.182      0.203      0.163      0.752      0.182      0.204      0.153
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.29G      1.226      2.536      2.244      1.392         65        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.613      0.273      0.321       0.21      0.613      0.273      0.309      0.191
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.37G      1.191      2.171      1.972      1.379         53        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.833      0.227      0.279      0.231      0.833      0.227       0.26      0.196
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.34G      1.076      1.887      1.646      1.429         53        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          7         22      0.596      0.318      0.281      0.192      0.513      0.273      0.252      0.164
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.35G      1.095      1.493      1.596      1.472         37        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          7         22      0.417      0.318      0.265      0.195      0.434      0.227      0.214      0.168
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.64G      1.216      1.873      1.426      1.532         48        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          7         22      0.301      0.273      0.189      0.136      0.254      0.227      0.134     0.0835
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.59G      1.066      1.548      1.428       1.27         65        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          7         22      0.355      0.364      0.215      0.142      0.313      0.318      0.191      0.125
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.56G       1.13      1.647      1.372      1.342         74        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.412      0.318      0.234      0.142      0.353      0.273      0.243      0.163
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       7.6G      1.091      1.742       1.37       1.31         59        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.386      0.273      0.271      0.156      0.328      0.364      0.285      0.164
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.61G       1.09      1.527      1.234      1.332         54        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.335      0.318      0.241      0.121      0.714      0.227      0.231      0.156
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      7.64G      1.016      1.419      1.152      1.313         49        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2it/s 0.2s
#                    all          7         22       0.35      0.318      0.208      0.122       0.35      0.318      0.217      0.136
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      7.62G      1.195      1.569      1.265      1.352         53        640: 100% ━━━━━━━━━━━━ 2/2 1.0it/s 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.231      0.273      0.116     0.0476      0.231      0.273      0.116     0.0551
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.54G      1.143      1.559      1.356      1.499         43        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22       0.25      0.136     0.0882     0.0481       0.25      0.136      0.103     0.0449
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      7.58G        1.2      1.832      1.496      1.446         49        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22     0.0222      0.136     0.0134    0.00614     0.0222      0.136     0.0127    0.00445
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      7.56G      1.122      1.804      1.518      1.391         56        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.6it/s 0.2s
#                    all          7         22        0.6      0.136      0.197     0.0665        0.6      0.136      0.144     0.0299
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      7.57G      1.285      1.717      1.324      1.455         58        640: 100% ━━━━━━━━━━━━ 2/2 0.9it/s 2.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          7         22        0.5      0.182      0.213     0.0855      0.375      0.136      0.118     0.0602
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      7.64G      1.211      1.777      1.285      1.302         70        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          7         22     0.0278        0.5     0.0357      0.023     0.0833     0.0455     0.0338     0.0127
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      7.53G      1.245      1.709      1.361       1.36         73        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22     0.0687      0.455      0.114     0.0403     0.0344      0.227     0.0268    0.00925
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      7.57G       1.35      1.892      1.436      1.429         61        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all          7         22      0.145      0.227     0.0937     0.0268     0.0596      0.273     0.0283    0.00395
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      7.62G      1.426      2.079        1.4      1.462         66        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.6it/s 0.2s
#                    all          7         22      0.167      0.182      0.086     0.0291     0.0633      0.318     0.0461     0.0161
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      7.61G      1.154      1.508      1.262       1.31         40        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.172      0.227      0.162     0.0747     0.0726      0.318     0.0468      0.014
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      7.49G      1.122      1.584      1.285      1.379         50        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.222      0.182     0.0803     0.0373     0.0528      0.364     0.0308     0.0102
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.55G      1.176      1.598      1.227      1.321         89        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          7         22      0.222      0.182      0.102     0.0439      0.222      0.182     0.0888     0.0172
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.56G      1.357      1.874      1.399      1.403         93        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          7         22      0.444      0.182      0.244      0.126      0.207      0.318      0.231     0.0915
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      7.47G      1.156      1.564      1.471      1.385         69        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.444      0.182      0.244      0.126      0.207      0.318      0.231     0.0915
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      7.56G       1.34      1.899      1.597      1.471         70        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          7         22      0.184      0.545      0.295        0.2      0.193      0.409      0.277      0.165
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      30/100       7.6G      1.274      1.891      1.467      1.419         57        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.197      0.409      0.231      0.129      0.175      0.364      0.202      0.117
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      7.48G      1.111      1.524      1.189      1.363         46        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.197      0.409      0.231      0.129      0.175      0.364      0.202      0.117
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      7.59G      1.125      1.421      1.126      1.336         55        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22        0.5      0.273      0.271     0.0928      0.417      0.227      0.171     0.0678
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      7.54G      1.228       1.56      1.489      1.306         78        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.278      0.227      0.117      0.058      0.278      0.227      0.117     0.0446
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      7.77G       1.19       1.58      1.338        1.4         39        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          7         22      0.278      0.227      0.117      0.058      0.278      0.227      0.117     0.0446
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      7.59G      1.156      1.518      1.232      1.342         69        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22        0.3      0.136      0.119     0.0575        0.3      0.136      0.112     0.0512
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      7.72G      0.985      1.238      1.201      1.236         39        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22     0.0842      0.273     0.0955     0.0415     0.0701      0.227     0.0826     0.0217
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      7.43G      1.083      1.723      1.178      1.268         67        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22     0.0842      0.273     0.0955     0.0415     0.0701      0.227     0.0826     0.0217
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      7.58G      1.083      1.411      1.159      1.338         66        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all          7         22        0.5     0.0909     0.0855     0.0368        0.5     0.0909     0.0795     0.0203
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      7.65G      1.062      1.523      1.099      1.195         89        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.333     0.0909     0.0991     0.0441      0.333     0.0909     0.0921     0.0258
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      7.79G      1.229       1.71       1.09      1.378         75        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          7         22      0.333     0.0909     0.0991     0.0441      0.333     0.0909     0.0921     0.0258
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      7.57G      1.101      1.541       1.07      1.285         83        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22        0.4     0.0909      0.101     0.0608     0.0486      0.182     0.0621     0.0486
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      7.65G      1.265      2.068      1.264      1.287         81        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.133      0.136      0.102     0.0664     0.0855     0.0909     0.0599     0.0492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      7.53G      1.275      1.713      1.258       1.44         42        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.133      0.136      0.102     0.0664     0.0855     0.0909     0.0599     0.0492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      7.58G       1.03      1.483      1.037      1.306         45        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          7         22      0.241      0.187      0.151     0.0917      0.269      0.182      0.137     0.0861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      7.61G      1.214      1.827      1.155       1.34         50        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.241      0.187      0.151     0.0917      0.269      0.182      0.137     0.0861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      7.61G      1.069       1.58      1.066      1.284         62        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          7         22      0.201      0.318      0.255      0.132      0.173      0.273      0.218      0.112
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      47/100       7.5G      1.139      1.498      1.066      1.314         60        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.201      0.318      0.255      0.132      0.173      0.273      0.218      0.112
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      7.68G      1.093      1.736      1.035       1.28         72        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.354      0.318      0.264      0.131      0.354      0.318      0.261      0.122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      7.59G       1.22      1.589      1.098      1.296         53        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.354      0.318      0.264      0.131      0.354      0.318      0.261      0.122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      7.59G     0.9694      1.276     0.9516      1.296         39        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.342      0.364      0.271      0.155      0.236      0.318      0.229      0.144
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      7.83G      1.201      1.437      1.168      1.346         48        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.342      0.364      0.271      0.155      0.236      0.318      0.229      0.144
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      7.61G      1.039      1.366     0.9994       1.25         61        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.258      0.364      0.203      0.109      0.258      0.364      0.199      0.111
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.55G     0.8993      1.066     0.8805      1.199         58        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.258      0.364      0.203      0.109      0.258      0.364      0.199      0.111
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.57G      1.058      1.369       1.01      1.244         56        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8it/s 0.3s
#                    all          7         22      0.194      0.364      0.169     0.0722      0.183      0.318      0.159     0.0717
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.34G      1.216      1.517      1.059      1.315         64        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.194      0.364      0.169     0.0722      0.183      0.318      0.159     0.0717
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      56/100       7.4G      1.027      1.296     0.9643      1.232         72        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.124      0.227     0.0537     0.0145      0.124      0.227     0.0995     0.0242
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      7.76G      1.009      1.073      1.061      1.344         43        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          7         22      0.124      0.227     0.0537     0.0145      0.124      0.227     0.0995     0.0242
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      7.58G      1.095      1.486      1.032      1.267         87        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.2s
#                    all          7         22     0.0889      0.136     0.0348    0.00911      0.119      0.182     0.0815     0.0186
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      7.73G       1.08      1.229      1.062        1.3         89        640: 100% ━━━━━━━━━━━━ 2/2 1.0it/s 2.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          7         22     0.0889      0.136     0.0348    0.00911      0.119      0.182     0.0815     0.0186
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      7.55G      1.145      1.194      1.081      1.349         57        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22     0.0605      0.182     0.0245    0.00974       0.12      0.136      0.055     0.0137
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      7.81G     0.9155      1.308     0.8612      1.114         65        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22     0.0605      0.182     0.0245    0.00974       0.12      0.136      0.055     0.0137
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.69G     0.9676      1.431     0.9223      1.202         60        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          7         22      0.129      0.227     0.0957     0.0484      0.129      0.227     0.0927     0.0537
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.51G      1.003      1.117     0.9718      1.244         38        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.129      0.227     0.0957     0.0484      0.129      0.227     0.0927     0.0537
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      7.62G     0.9014        1.4      0.842      1.116         83        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.283      0.455      0.276      0.129      0.283      0.455      0.267      0.122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      7.34G      0.927      1.226     0.9448      1.231         46        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.283      0.455      0.276      0.129      0.283      0.455      0.267      0.122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.34G     0.9824      1.284     0.8616      1.164         68        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          7         22      0.418        0.5      0.304      0.149      0.418        0.5      0.299      0.166
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      7.39G       1.06      1.106     0.9129      1.221         70        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          7         22      0.418        0.5      0.304      0.149      0.418        0.5      0.299      0.166
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      7.56G     0.9296       1.09     0.8525      1.225         54        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8it/s 0.3s
#                    all          7         22      0.433      0.487      0.331      0.186      0.433      0.487      0.307       0.16
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      7.45G     0.8828      1.132     0.9025      1.226         61        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.9it/s 0.2s
#                    all          7         22      0.433      0.487      0.331      0.186      0.433      0.487      0.307       0.16
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      7.64G     0.9054      1.076      0.918      1.165         57        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.447      0.318      0.236       0.13      0.382      0.273       0.18      0.107
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      7.48G     0.8739      1.057     0.7512      1.144         75        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          7         22      0.447      0.318      0.236       0.13      0.382      0.273       0.18      0.107
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.63G     0.8728       1.06     0.8264      1.173         56        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.417      0.409      0.266      0.178      0.373      0.364      0.238      0.158
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.76G     0.8275     0.9007     0.7523      1.199         44        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.417      0.409      0.266      0.178      0.373      0.364      0.238      0.158
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.53G     0.7554     0.8633     0.7346      1.164         36        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          7         22      0.488      0.364      0.333       0.21       0.59      0.409      0.351      0.206
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.48G     0.8454     0.9447     0.8301      1.159         52        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.488      0.364      0.333       0.21       0.59      0.409      0.351      0.206
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      7.54G      1.036      1.348     0.9807      1.194        122        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all          7         22      0.621      0.409      0.393      0.248      0.814      0.364      0.408      0.205
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.41G     0.8732     0.9685     0.8137      1.154         74        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          7         22      0.621      0.409      0.393      0.248      0.814      0.364      0.408      0.205
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      78/100       7.6G     0.8966      1.259     0.8198      1.159         68        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         22      0.619      0.409      0.424      0.264      0.666      0.362      0.374      0.229
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.48G     0.8373     0.8763     0.6733      1.247         56        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          7         22      0.619      0.409      0.424      0.264      0.666      0.362      0.374      0.229
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.67G     0.9012      1.117     0.7416      1.101         67        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          7         22      0.775      0.313      0.393      0.234       0.73      0.273      0.321      0.222
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.52G     0.8691       1.35     0.8813      1.171         56        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
# ...
#                    all          7         31      0.425      0.501      0.436      0.156      0.468      0.355      0.366      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.53G     0.7983     0.9895     0.7967      1.102         52        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          7         31      0.425      0.501      0.436      0.156      0.468      0.355      0.366      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.55G     0.6881     0.7374     0.7998      1.086         36        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.548      0.613      0.425      0.157       0.49      0.548      0.361      0.146
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      75/100       7.8G     0.8508      1.182     0.8807      1.159         39        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.548      0.613      0.425      0.157       0.49      0.548      0.361      0.146
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      7.55G     0.8346     0.8164     0.8176      1.206         57        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          7         31      0.332      0.645      0.333      0.172      0.335      0.581      0.326      0.167
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.76G     0.7658     0.9511     0.7271      1.094         57        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all          7         31      0.332      0.645      0.333      0.172      0.335      0.581      0.326      0.167
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      78/100       7.6G     0.9725     0.9647     0.8371       1.14         64        640: 100% ━━━━━━━━━━━━ 2/2 1.0it/s 2.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          7         31      0.383      0.452       0.34      0.207      0.369      0.419      0.348      0.194
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.78G     0.7516     0.9315     0.7587      1.102         67        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          7         31      0.383      0.452       0.34      0.207      0.369      0.419      0.348      0.194
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      80/100       7.6G     0.7639     0.8889      0.736      1.078         58        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.483      0.387      0.348        0.2      0.416      0.419      0.334      0.192
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.48G     0.8099      0.955     0.6998      1.093         55        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          7         31      0.483      0.387      0.348        0.2      0.416      0.419      0.334      0.192
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.59G     0.8247      1.018     0.7227      1.071         62        640: 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.512      0.419      0.358      0.198      0.472      0.387      0.335      0.187
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.52G     0.7749     0.9725     0.7137      1.119         56        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.512      0.419      0.358      0.198      0.472      0.387      0.335      0.187
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.56G     0.6839     0.9144     0.6347      1.045         71        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                    all          7         31      0.509      0.355      0.364      0.205      0.449      0.419      0.354      0.206
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.46G     0.6615     0.8251     0.7439      1.074         47        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          7         31      0.509      0.355      0.364      0.205      0.449      0.419      0.354      0.206
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.55G     0.7679     0.9275     0.7407      1.087         57        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          7         31        0.5      0.419      0.404      0.224      0.452      0.452      0.398      0.234
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.53G      0.582     0.7239     0.6139     0.9936         46        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          7         31        0.5      0.419      0.404      0.224      0.452      0.452      0.398      0.234
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.59G     0.7737      1.052     0.7214      1.082         52        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          7         31      0.423      0.452      0.405      0.231      0.453      0.484      0.425      0.246
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.48G     0.6982     0.7743     0.6109      1.088         72        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          7         31      0.423      0.452      0.405      0.231      0.453      0.484      0.425      0.246
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.58G     0.6733     0.7325     0.6427       1.11         47        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          7         31       0.58      0.419      0.446      0.243      0.625      0.452      0.457      0.254
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      91/100       7.7G     0.6074     0.8423     0.7429      1.047         23        640: 100% ━━━━━━━━━━━━ 2/2 0.7it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1it/s 0.5s
#                    all          7         31       0.58      0.419      0.446      0.243      0.625      0.452      0.457      0.254
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.52G     0.8688     0.8643     0.8243      1.273         24        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          7         31      0.622      0.419      0.459      0.258       0.67      0.452      0.463      0.256
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      93/100       7.4G     0.6737      1.572     0.6733      1.095         24        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          7         31      0.622      0.419      0.459      0.258       0.67      0.452      0.463      0.256
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       7.5G     0.5353       1.04     0.5945      0.953         28        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.6it/s 0.2s
#                    all          7         31       0.65       0.42      0.483       0.27        0.7      0.452      0.494      0.272
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.67G     0.5838     0.7962     0.6018      1.044         34        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          7         31       0.65       0.42      0.483       0.27        0.7      0.452      0.494      0.272
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.49G     0.5823     0.7145     0.5741      1.045         29        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          7         31      0.698      0.448      0.487      0.273      0.748      0.478      0.495      0.275
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      97/100       7.4G      0.519      0.816     0.5448     0.9355         28        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          7         31      0.698      0.448      0.487      0.273      0.748      0.478      0.495      0.275
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.53G     0.5702     0.8424     0.5542      1.029         25        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          7         31      0.647      0.474      0.499      0.284      0.735      0.452      0.505      0.285
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.69G     0.5758     0.6906     0.5614       1.07         24        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          7         31      0.647      0.474      0.499      0.284      0.735      0.452      0.505      0.285
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.52G     0.5763     0.7469     0.5273      1.064         28        640: 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          7         31      0.669      0.484      0.498       0.29      0.715      0.484      0.502      0.285
#
# 100 epochs completed in 0.273 hours.
# Optimizer stripped from /content/runs/segment/yolov8m_seg_session_52/weights/last.pt, 54.8MB
# Optimizer stripped from /content/runs/segment/yolov8m_seg_session_52/weights/best.pt, 54.8MB
#
# Validating /content/runs/segment/yolov8m_seg_session_52/weights/best.pt...
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,222,963 parameters, 0 gradients, 104.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          7         31      0.669      0.484      0.498      0.293      0.711      0.484      0.502      0.285
# Speed: 0.2ms preprocess, 18.3ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to /content/runs/segment/yolov8m_seg_session_52
# Session 5 Training Time: 999.59 seconds (16.66 minutes)
# Saved session 5 artifacts (results, weights, plots) to /content/drive/MyDrive/5 fold training/5_fold_ACV_outputs/5-Fold Baseline,session 5

# %% [markdown]
# **Cell 5: Compute and Print Results - This cell calculates the average metrics across all sessions and prints both the averages and per-session details.**

# %%
# After all sessions, compute averages
avg_Box_P = sum(r['Box_P'] for r in session_results) / 5
avg_Box_R = sum(r['Box_R'] for r in session_results) / 5
avg_Box_mAP50 = sum(r['Box_mAP50'] for r in session_results) / 5
avg_Box_mAP50_95 = sum(r['Box_mAP50-95'] for r in session_results) / 5
avg_Mask_P = sum(r['Mask_P'] for r in session_results) / 5
avg_Mask_R = sum(r['Mask_R'] for r in session_results) / 5
avg_Mask_mAP50 = sum(r['Mask_mAP50'] for r in session_results) / 5
avg_Mask_mAP50_95 = sum(r['Mask_mAP50-95'] for r in session_results) / 5
avg_training_time = sum(r['training_time_seconds'] for r in session_results) / 5

print("\nCross-Validation Average Results:")
print(f"Average Box (P): {avg_Box_P:.4f}")
print(f"Average Box (R): {avg_Box_R:.4f}")
print(f"Average Box (mAP50): {avg_Box_mAP50:.4f}")
print(f"Average Box (mAP50-95): {avg_Box_mAP50_95:.4f}")
print(f"Average Mask (P): {avg_Mask_P:.4f}")
print(f"Average Mask (R): {avg_Mask_R:.4f}")
print(f"Average Mask (mAP50): {avg_Mask_mAP50:.4f}")
print(f"Average Mask (mAP50-95): {avg_Mask_mAP50_95:.4f}")
print(f"Average Training Time: {avg_training_time:.2f} seconds ({avg_training_time / 60:.2f} minutes)")

print("\nPer-Session Results:")
for r in session_results:
    print(f"Session {r['session']}:")
    print(f"  Training Folders: {r['train_folders']}")
    print(f"  Validation Folder: {r['val_folder']}")
    print(f"  Validation Images: {r['num_val_images']}, Instances: {r['num_val_instances']}")
    print(f"  Training Images: {r['num_train_images']}, Instances: {r['num_train_instances']}")
    print(f"  Box (P): {r['Box_P']:.4f}")
    print(f"  Box (R): {r['Box_R']:.4f}")
    print(f"  Box (mAP50): {r['Box_mAP50']:.4f}")
    print(f"  Box (mAP50-95): {r['Box_mAP50-95']:.4f}")
    print(f"  Mask (P): {r['Mask_P']:.4f}")
    print(f"  Mask (R): {r['Mask_R']:.4f}")
    print(f"  Mask (mAP50): {r['Mask_mAP50']:.4f}")
    print(f"  Mask (mAP50-95): {r['Mask_mAP50-95']:.4f}")
    print(f"  Training Time: {r['training_time_seconds']:.2f} seconds ({r['training_time_seconds'] / 60:.2f} minutes)")

import pandas as pd
df = pd.DataFrame(session_results)
agg_save_path = os.path.join(base_output_dir, f"{dataset_name}_aggregated_results.csv")
df.to_csv(agg_save_path, index=False)
#print(f"Saved aggregated results to {agg_save_path}")

# Models are saved in /content/runs/segment/yolov8m_seg_session_X/weights/best.pt
# You can average them or pick the best session manually if needed.
#If a session crashes, you can resume by loading last.pt from the saved folder (e.g., set model = YOLO(os.path.join(custom_save_dir, 'weights/last.pt')) and use resume=True in train()).
# Out:
# Cross-Validation Average Results:
# Average Box (P): 0.8113
# Average Box (R): 0.5947
# Average Box (mAP50): 0.6335
# Average Box (mAP50-95): 0.4437
# Average Mask (P): 0.8277
# Average Mask (R): 0.6052
# Average Mask (mAP50): 0.6351
# Average Mask (mAP50-95): 0.4360
# Average Training Time: 767.30 seconds (12.79 minutes)
#
# Per-Session Results:
# Session 1:
#   Training Folders: Data2, Data3, Data4, Data5
#   Validation Folder: Data1
#   Validation Images: 7, Instances: 22
#   Training Images: 28, Instances: 70
#   Box (P): 0.8944
#   Box (R): 0.4545
#   Box (mAP50): 0.5596
#   Box (mAP50-95): 0.4082
#   Mask (P): 0.8944
#   Mask (R): 0.4545
#   Mask (mAP50): 0.5682
#   Mask (mAP50-95): 0.3874
#   Training Time: 388.11 seconds (6.47 minutes)
# Session 2:
#   Training Folders: Data1, Data3, Data4, Data5
#   Validation Folder: Data2
#   Validation Images: 7, Instances: 19
#   Training Images: 28, Instances: 73
#   Box (P): 0.6685
#   Box (R): 0.3684
#   Box (mAP50): 0.3992
#   Box (mAP50-95): 0.2294
#   Mask (P): 0.7077
#   Mask (R): 0.4211
#   Mask (mAP50): 0.4285
#   Mask (mAP50-95): 0.2719
#   Training Time: 735.98 seconds (12.27 minutes)
# Session 3:
#   Training Folders: Data1, Data2, Data4, Data5
#   Validation Folder: Data3
#   Validation Images: 7, Instances: 8
#   Training Images: 28, Instances: 84
#   Box (P): 0.8353
#   Box (R): 1.0000
#   Box (mAP50): 0.9672
#   Box (mAP50-95): 0.7671
#   Mask (P): 0.8353
#   Mask (R): 1.0000
#   Mask (mAP50): 0.9672
#   Mask (mAP50-95): 0.8121
#   Training Time: 936.71 seconds (15.61 minutes)
# Session 4:
#   Training Folders: Data1, Data2, Data3, Data5
#   Validation Folder: Data4
#   Validation Images: 7, Instances: 12
#   Training Images: 28, Instances: 80
#   Box (P): 0.9901
#   Box (R): 0.6667
#   Box (mAP50): 0.7437
#   Box (mAP50-95): 0.5212
#   Mask (P): 0.9901
#   Mask (R): 0.6667
#   Mask (mAP50): 0.7100
#   Mask (mAP50-95): 0.4236
#   Training Time: 776.14 seconds (12.94 minutes)
# Session 5:
#   Training Folders: Data1, Data2, Data3, Data4
#   Validation Folder: Data5
#   Validation Images: 7, Instances: 31
#   Training Images: 28, Instances: 61
#   Box (P): 0.6685
#   Box (R): 0.4839
#   Box (mAP50): 0.4979
#   Box (mAP50-95): 0.2927
#   Mask (P): 0.7113
#   Mask (R): 0.4839
#   Mask (mAP50): 0.5018
#   Mask (mAP50-95): 0.2850
#   Training Time: 999.59 seconds (16.66 minutes)
